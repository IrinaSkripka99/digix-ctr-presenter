# %% [markdown]
# # Разбор данных
#
# Этот анализ поможет познакомиться с набором данных и найти подходящие признаки.

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
from EDA import EDA

# %%
pd.set_option('display.max_columns', 40)

# %% [markdown]
# Pandas не может обрабатывать данные 6G, просто читая их,поэтому будет использоваться spark

# %%
import findspark
findspark.init()
findspark.find()
# Out:
# 'C:\\spark-3.1.1-bin-hadoop2.7'

# %%
import pyspark

# %% [markdown]
# # Загрузка данных

# %%
data_dir = "./data/sampled_data.csv/"

df = pd.DataFrame()
for file in os.listdir(data_dir):    
    if file[-3:] == "csv":
        df = pd.concat((df,pd.read_csv(os.path.join(data_dir,file))),axis=0)

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

# %%
spark.sparkContext.getConf().getAll()
# Out:
# [('spark.app.startTime', '1621188208763'),
#  ('spark.driver.port', '49347'),
#  ('spark.app.id', 'local-1621188211457'),
#  ('spark.rdd.compress', 'True'),
#  ('spark.serializer.objectStreamReset', '100'),
#  ('spark.driver.host', 'DESKTOP-V7GSFHS'),
#  ('spark.master', 'local[*]'),
#  ('spark.submit.pyFiles', ''),
#  ('spark.executor.id', 'driver'),
#  ('spark.submit.deployMode', 'client'),
#  ('spark.ui.showConsoleProgress', 'true'),
#  ('spark.app.name', 'pyspark-shell')]

# %%
data_dir = "./data"
data_file_name = "train_data.csv"
data_path = os.path.join(data_dir,data_file_name)

raw_df = spark.read.load(data_path,format="csv",delimiter="|",header=True)

# %% [markdown]
# # Анализ датасета

# %%
raw_df_shape = (raw_df.count(),len(raw_df.columns))
print(f"The shape: {raw_df_shape}")
# Out:
# The shape: (41907133, 36)

# %%
# первые 5
raw_df_head = [row.asDict() for row in raw_df.head(5)]
pd.DataFrame(raw_df_head)
# Out:
#   label      uid task_id adv_id creat_type_cd adv_prim_id dev_id  \
# 0     0  1638254    2112   6869             7         207     17
# 1     0  1161786    3104   3247             7         183     29
# 2     0  1814783    5890   4183             7         178     17
# 3     0  1468996    1993   5405             7         207     17
# 4     0  2164010    5439   4677             2         138     24
#
#   inter_type_cd slot_id spread_app_id tags app_first_class app_second_class  \
# 0             5      11            13   37               4               21
# 1             5      17            86   37               4               21
# 2             5      11            70   39               4               17
# 3             5      21            13   37               4               21
# 4             5      12            33   15               4               15
#
#   age city city_rank device_name device_size career gender net_type residence  \
# ...

# %%
# последние 5
raw_df_tail = [row.asDict() for row in raw_df.tail(5)]
pd.DataFrame(raw_df_tail)
# Out:
#   label      uid task_id adv_id creat_type_cd adv_prim_id dev_id  \
# 0     0  2154906    5275   5473             7         156     56
# 1     0  1466996    5952   4158             7         207     17
# 2     0  1930657    2178   1860             2         142     60
# 3     0  1550398    1976   6739             7         154     56
# 4     0  1400807    3869   6751             7         130     30
#
#   inter_type_cd slot_id spread_app_id tags app_first_class app_second_class  \
# 0             5      13            58   37               4               21
# 1             5      17            13   37               4               21
# 2             5      12            80   41               2               26
# 3             5      11            31   40               4               25
# 4             5      13            28   39               4               17
#
#   age city city_rank device_name device_size career gender net_type residence  \
# ...

# %%
# типы данных
raw_df.schema.fields
# Out:
# [StructField(label,StringType,true),
#  StructField(uid,StringType,true),
#  StructField(task_id,StringType,true),
#  StructField(adv_id,StringType,true),
#  StructField(creat_type_cd,StringType,true),
#  StructField(adv_prim_id,StringType,true),
#  StructField(dev_id,StringType,true),
#  StructField(inter_type_cd,StringType,true),
#  StructField(slot_id,StringType,true),
#  StructField(spread_app_id,StringType,true),
#  StructField(tags,StringType,true),
#  StructField(app_first_class,StringType,true),
#  StructField(app_second_class,StringType,true),
#  StructField(age,StringType,true),
#  StructField(city,StringType,true),
#  StructField(city_rank,StringType,true),
#  StructField(device_name,StringType,true),
#  StructField(device_size,StringType,true),
#  StructField(career,StringType,true),
#  StructField(gender,StringType,true),
#  StructField(net_type,StringType,true),
#  StructField(residence,StringType,true),
#  StructField(his_app_size,StringType,true),
# ...

# %%
raw_df.columns
# Out:
# ['label',
#  'uid',
#  'task_id',
#  'adv_id',
#  'creat_type_cd',
#  'adv_prim_id',
#  'dev_id',
#  'inter_type_cd',
#  'slot_id',
#  'spread_app_id',
#  'tags',
#  'app_first_class',
#  'app_second_class',
#  'age',
#  'city',
#  'city_rank',
#  'device_name',
#  'device_size',
#  'career',
#  'gender',
#  'net_type',
#  'residence',
#  'his_app_size',
#  'his_on_shelf_time',
#  'app_score',
#  'emui_dev',
#  'list_time',
#  'device_price',
#  'up_life_duration',
#  'up_membership_grade',
#  'membership_life_duration',
#  'consume_purchase',
#  'communication_onlinerate',
#  'communication_avgonline_30d',
#  'indu_name',
#  'pt_d']

# %%
# вовзращаем некоторые общие данные по каждому признаку
describe = raw_df.describe()
describe.toPandas().set_index("summary").T
# Out:
# summary                         count                  mean  \
# label                        41907133  0.034492648304048856
# uid                          41907133    1618366.5450654665
# task_id                      41907133    3436.3739258660335
# adv_id                       41907133      3963.51341013951
# creat_type_cd                41907133     6.490081748135813
# adv_prim_id                  41907133    159.31912006483478
# dev_id                       41907133     41.59357343772479
# inter_type_cd                41907133     4.646959504483402
# slot_id                      41907133    15.254736109005595
# spread_app_id                41907133      51.9989373646725
# tags                         41907133     34.36324749297452
# app_first_class              41907133    3.5649967751313363
# app_second_class             41907133    22.091261146401973
# age                          41907133     5.055212772489113
# city                         41907133     265.4613547531395
# ...

# %% [markdown]
# Большинство столбцов являются категориальными переменными, поэтому не имеет смысла отслеживать эту статистику.Для начала нужно доказать это

# %%
numeric_columns = ["age","device_size",'his_app_size','app_score','device_price']

# %%
describe = raw_df.select(numeric_columns).describe()
describe.toPandas().set_index("summary").T
# Out:
# summary          count                mean               stddev  min  max
# age           41907133   5.055212772489113   1.4153192617965202   -1    7
# device_size   41907133   158.2104430527376    45.07228338655767  101  349
# his_app_size  41907133  6.5524609378551375    5.898097528503572   -1    9
# app_score     41907133  1.7847627037621494  0.41098686910490795    1    2
# device_price  41907133   3.476986387973618   1.1587958240779863   -1    7

# %% [markdown]
# Кажется, что даже это числовые переменные, но они уже сгруппированы по разным уровням.
# Поскольку дальнейших объяснений нет, можно сделать несколько предположений:
# 1. значение = -1 равно отсутствующему значению
# 2. значение app_score - это фактическая оценка
# 3. Цена устройства 1-7 означает, что от дешевого к дорогому.
# 4. Возраст 1–7 лет означает от мала до велика.
#
# Это открытие означает, что при обработке данных для моделей нужно создать множество фиктивных переменных.

# %% [markdown]
# # Исследование данныx

# %% [markdown]
# ## label

# %%
label_count = raw_df.select("label").groupby("label").count().toPandas()

# %%
label_count["pct"] = np.round(label_count["count"].values/raw_df_shape[0],decimals=3)
label_count
# Out:
#   label     count    pct
# 0     0  40461645  0.966
# 1     1   1445488  0.034

# %%
plot = sns.barplot(label_count["label"].values,label_count["count"].values/raw_df_shape[0])
# Out:
# C:\Users\irina\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Распределение кликов несбалансированное. Но это ожидаемо. Это означает, что CTR в этом наборе данных составляет около 3,5%, что лучше, чем средний показатель CTR.
# <img src = "images/avg_ctr.png">

# %% [raw]
# ## признаки с ID

# %%
raw_df.columns
# Out:
# ['label',
#  'uid',
#  'task_id',
#  'adv_id',
#  'creat_type_cd',
#  'adv_prim_id',
#  'dev_id',
#  'inter_type_cd',
#  'slot_id',
#  'spread_app_id',
#  'tags',
#  'app_first_class',
#  'app_second_class',
#  'age',
#  'city',
#  'city_rank',
#  'device_name',
#  'device_size',
#  'career',
#  'gender',
#  'net_type',
#  'residence',
#  'his_app_size',
#  'his_on_shelf_time',
#  'app_score',
#  'emui_dev',
#  'list_time',
#  'device_price',
#  'up_life_duration',
#  'up_membership_grade',
#  'membership_life_duration',
#  'consume_purchase',
#  'communication_onlinerate',
#  'communication_avgonline_30d',
#  'indu_name',
#  'pt_d']

# %%
id_columns = ['uid','task_id','adv_id','creat_type_cd','adv_prim_id','dev_id','inter_type_cd','slot_id','spread_app_id']

# %%
from pyspark.sql import functions as F

# %%
for col in id_columns:
    raw_df.select(F.countDistinct(col)).distinct().show()
# Out:
# +-------------------+
# |count(DISTINCT uid)|
# +-------------------+
# |            1081436|
# +-------------------+
#
# +-----------------------+
# |count(DISTINCT task_id)|
# +-----------------------+
# |                   4329|
# +-----------------------+
#
# +----------------------+
# |count(DISTINCT adv_id)|
# +----------------------+
# |                  5319|
# +----------------------+
#
# +-----------------------------+
# |count(DISTINCT creat_type_cd)|
# +-----------------------------+
# |                            8|
# +-----------------------------+
#
# +---------------------------+
# |count(DISTINCT adv_prim_id)|
# +---------------------------+
# |                        101|
# +---------------------------+
#
# +----------------------+
# |count(DISTINCT dev_id)|
# +----------------------+
# |                    55|
# +----------------------+
#
# +-----------------------------+
# |count(DISTINCT inter_type_cd)|
# +-----------------------------+
# ...

# %% [markdown]
# Посмотрев внимательно на столбцы идентификаторов, обнаружено следующее:
# 1. некоторые признаки на самом деле являются идентификаторами, некоторые - нет.
# 2. некоторые значения идентификаторов фактически являются признакми для других функций более высокого уровня.(взаимосвязаны)
#
# На основе этих двух результатов построена следующая карта признаков:
#
# 1. users:
#     - uid
#     - age
#     - city
#         - city_rank
#         - residence
#     - career
#     - gender
#     - up_life_duration
#     - up_membership_grade
#     - membership_life_duration
#     - consume_purchase
#     - communication_onlinerate
#     - communication_avgonline_30d
# 2. ads
#     - task_id
#     - adv_id
#     - creat_type_cd
#     - adv_prim_id
#     - dev_id
#     - inter_typ_cd
#     - slot_id
#     - indu_name
# 3. apps
#     - spread_app_id
#     - tags
#     - app_first_class
#     - app_second_class
#     - his_app_size
#     - his_on_shelf_time
#     - app_score
# 4. device
#     - device_name
#     - device_size
#     - emui_dev
#     - list_time
#     - device_price
# 6. behavior/event
#     - net_type
#     - pt_d
#
# Исследование признаков будет происходить следуя этой группировке

# %% [markdown]
# ## Users
#
# users:
# - uid
# - age
# - city
#     - city_rank
#     - residence
# - career
# - gender
# - up_life_duration
# - up_membership_grade
# - membership_life_duration
# - consume_purchase
# - communication_onlinerate
# - communication_avgonline_30d

# %% [markdown]
# ### uid

# %%
# Создание экземпляра объекта EDA
eda = EDA(target_ctr=0.035)
# преобразовываем label в integer
raw_df = raw_df.withColumn("label_int",raw_df["label"].cast("integer"))

# %%
high_ctr_uids, low_ctr_uids = eda.id_analysis(raw_df,"uid")
# Out:
# CTR distribution by uid
# count    1.081436e+06
# mean     1.488611e-01
# std      1.990887e-01
# min      0.000000e+00
# 25%      1.515152e-02
# 50%      6.000000e-02
# 75%      2.000000e-01
# max      1.000000e+00
# Name: uid_ctr, dtype: float64
# C:\Users\irina\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
user_features = ["age",   
                 "city_rank",
                 "residence",
                 "career",
                 "gender",
                 "up_life_duration",
                 "up_membership_grade",
                 "membership_life_duration",
                 "consume_purchase",
                 "communication_avgonline_30d"
                ]

# %%
for feature in user_features:
    print(f"Анализ {feature}")
    eda.cat_analysis(raw_df,feature,"uid")
    eda.click_not_click_distrubitions(raw_df,feature)
    print("")
    print("="*20)
    print("")
# Out:
# Анализ age
# CTR
# distributions of click or not
# ...
#
# Анализ city_rank
# CTR
# distributions of click or not
# ...
#
# Анализ residence
# CTR
# distributions of click or not
# ...
#
# Анализ career
# CTR
# distributions of click or not
# ...
#
# Анализ gender
# CTR
# distributions of click or not
# ...
#
# Анализ up_life_duration
# CTR
# distributions of click or not
# ...
#
# Анализ up_membership_grade
# CTR
# distributions of click or not
# ...
#
# Анализ membership_life_duration
# CTR
# distributions of click or not
# ...
#
# Анализ consume_purchase
# CTR
# distributions of click or not
# ...
#
# Анализ communication_avgonline_30d
# CTR
# distributions of click or not
# ...

# %% [markdown]
# ## communication_onlinerate

# %%
raw_df.select(F.split(raw_df.communication_onlinerate,"^")).show()
# Out:
# +--------------------------------------+
# |split(communication_onlinerate, ^, -1)|
# +--------------------------------------+
# |                  [0^1^2^3^4^5^6^7^...|
# |                  [3^4^5^6^7^8^9^10...|
# |                  [0^1^2^3^4^5^6^7^...|
# |                  [5^6^7^8^9^10^11^...|
# |                  [2^3^4^5^6^7^8^9^...|
# |                  [6^7^8^9^10^11^12...|
# |                  [0^1^2^3^4^5^6^7^...|
# |                  [14^15^16^17^18^1...|
# |                  [1^2^3^4^5^6^7^8^...|
# |                  [6^7^8^9^10^11^12...|
# |                  [6^7^8^9^10^11^12...|
# |                            [21^22^23]|
# |                  [2^3^4^5^6^7^8^9^...|
# |                  [6^7^8^9^10^11^12...|
# |                  [4^5^6^7^8^9^10^1...|
# |                  [7^8^9^10^11^12^1...|
# |                  [6^7^8^9^10^11^12...|
# |                  [6^7^8^9^10^11^12...|
# |                  [4^5^6^7^8^9^10^1...|
# |                  [6^7^8^9^10^11^12...|
# ...

# %%
# парсинг только начала и окончания времени
raw_df = raw_df.withColumn("start_communication_onlinerate",raw_df.communication_onlinerate.substr(1,2))
raw_df = raw_df.withColumn("start_communication_onlinerate",F.regexp_extract(raw_df.start_communication_onlinerate,r'(\d+)',1))
raw_df = raw_df.withColumn("last_communication_onlinerate",raw_df.communication_onlinerate.substr(-2,2))
raw_df = raw_df.withColumn("last_communication_onlinerate",F.regexp_extract(raw_df.last_communication_onlinerate,r'(\d+)',1))

raw_df.select("start_communication_onlinerate","last_communication_onlinerate").show()
# Out:
# +------------------------------+-----------------------------+
# |start_communication_onlinerate|last_communication_onlinerate|
# +------------------------------+-----------------------------+
# |                             0|                           23|
# |                             3|                           23|
# |                             0|                           23|
# |                             5|                           23|
# |                             2|                           23|
# |                             6|                           23|
# |                             0|                           23|
# |                            14|                           23|
# |                             1|                           23|
# |                             6|                           23|
# |                             6|                           23|
# |                            21|                           23|
# ...

# %%
# сделать окончание на 0 преобразовать в 24
raw_df = raw_df.withColumn("last_communication_onlinerate"\
                           ,F.when(raw_df.last_communication_onlinerate == 0, 24)\
                           .otherwise(raw_df.last_communication_onlinerate))

# %%
# рассчитать продолжительность пробывания онлайн в этот день
raw_df = raw_df.withColumn("duration_communication_onlinerate"\
                  ,raw_df.last_communication_onlinerate-raw_df.start_communication_onlinerate)
raw_df = raw_df.withColumn("duration_communication_onlinerate",raw_df["duration_communication_onlinerate"].cast("integer").cast("string"))

# %%
for feature in ["start_communication_onlinerate","last_communication_onlinerate","duration_communication_onlinerate"]:
    print(f"Анализ {feature}")
    eda.cat_analysis(raw_df,feature,"uid")
    eda.click_not_click_distrubitions(raw_df,feature)
    print("")
    print("="*20)
    print("")
# Out:
# Анализ start_communication_onlinerate
# CTR
# distributions of click or not
# ...
#
# Анализ last_communication_onlinerate
# CTR
# distributions of click or not
# ...
#
# Анализ duration_communication_onlinerate
# CTR
# distributions of click or not
# ...

# %% [markdown]
# # Ads

# %% [markdown]
# Информации об отличии task_id от adv_id нет, и просмотрев последовательность, найти ничего не получилось, но похоже, что большинство рекламных функций принадлежат task_id, и поэтому будет использоваться task_id в качестве основного идентификатора рекламы.

# %%
ads_features = ["creat_type_cd",
                "adv_prim_id",
                "dev_id",
                "inter_type_cd",
                "slot_id",
                "indu_name"]

# %%
high_ctr_task_ids, low_ctr_task_ids = eda.id_analysis(raw_df,"task_id")
# Out:
# CTR distribution by task_id
# count    4329.000000
# mean        0.025977
# std         0.046705
# min         0.000000
# 25%         0.011905
# 50%         0.019476
# 75%         0.029167
# max         1.000000
# Name: task_id_ctr, dtype: float64
# C:\Users\irina\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
for feature in ads_features:
    print(f"Анализ {feature}")
    eda.cat_analysis(raw_df,feature,"task_id")
    eda.click_not_click_distrubitions(raw_df,feature)
    print("")
    print("="*20)
    print("")
# Out:
# Анализ creat_type_cd
# CTR
# distributions of click or not
# ...
#
# Анализ adv_prim_id
# CTR
# distributions of click or not
# ...
#
# Анализ dev_id
# CTR
# distributions of click or not
# ...
#
# Анализ inter_type_cd
# CTR
# distributions of click or not
# ...
#
# Анализ slot_id
# CTR
# distributions of click or not
# ...
#
# Анализ indu_name
# CTR
# distributions of click or not
# ...

# %% [markdown]
# # Apps

# %%
app_features = ["tags",
                "app_first_class",
                "app_second_class",
                "his_app_size",
                "his_on_shelf_time",
                "app_score"]

# %%
high_ctr_app_ids, low_ctr_app_ids = eda.id_analysis(raw_df,"spread_app_id")
# Out:
# CTR distribution by spread_app_id
# count    70.000000
# mean      0.024271
# std       0.015070
# min       0.000000
# 25%       0.015687
# 50%       0.019712
# 75%       0.027392
# max       0.091297
# Name: spread_app_id_ctr, dtype: float64
# C:\Users\irina\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
for feature in app_features:
    print(f"АНализ {feature}")
    eda.cat_analysis(raw_df,feature,"spread_app_id")
    eda.click_not_click_distrubitions(raw_df,feature)
    print("")
    print("="*20)
    print("")
# Out:
# АНализ tags
# CTR
# distributions of click or not
# ...
#
# АНализ app_first_class
# CTR
# distributions of click or not
# ...
#
# АНализ app_second_class
# CTR
# distributions of click or not
# ...
#
# АНализ his_app_size
# CTR
# distributions of click or not
# ...
#
# АНализ his_on_shelf_time
# CTR
# distributions of click or not
# ...
#
# АНализ app_score
# CTR
# distributions of click or not
# ...

# %% [markdown]
# # Device

# %%
device_features = ["device_size",
                   "emui_dev",
                   "list_time",
                   "device_price"]

# %%
high_ctr_device_ids, low_ctr_device_ids = eda.id_analysis(raw_df,"device_name")
# Out:
# CTR distribution by device_name
# count    91.000000
# mean      0.044774
# std       0.024143
# min       0.000000
# 25%       0.028903
# 50%       0.041027
# 75%       0.050949
# max       0.200000
# Name: device_name_ctr, dtype: float64
# C:\Users\irina\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
for feature in device_features:
    print(f"Анализ {feature}")
    eda.cat_analysis(raw_df,feature,"device_name")
    eda.click_not_click_distrubitions(raw_df,feature)
    print("")
    print("="*20)
    print("")
# Out:
# Анализ device_size
# CTR
# distributions of click or not
# ...
#
# Анализ emui_dev
# CTR
# distributions of click or not
# ...
#
# Анализ list_time
# CTR
# distributions of click or not
# ...
#
# Анализ device_price
# CTR
# distributions of click or not
# ...

# %% [markdown]
# # Environment

# %%
eda.cat_analysis(raw_df,"net_type","net_type")
# Out:
# CTR

# %%
eda.click_not_click_distrubitions(raw_df,"net_type")
# Out:
# distributions of click or not

# %%
eda.cat_analysis(raw_df,"pt_d","pt_d")
# Out:
# CTR

# %%
eda.click_not_click_distrubitions(raw_df,"pt_d")
# Out:
# distributions of click or not

# %% [markdown]
# ## Итоги
# 1. **Users:**
#     - **uid**: согласно базовой статистике, распространению и cdf, 25% пользователей имеют CTR выше 0,2. Это намного больше 0,03. Поэтому для пользователей будет определяться, что CTR выше 0,2 - это более высокий CTR. В следующем шаге анализа я сравню распределение характеристик для группы с высоким и низким CTR, чтобы выявить какие-либо значимые различия.
#
#     - **age**: люди, которые не сообщили о своем возрасте, как правило, имеют более высокий CTR. **Это может быть хорошей новой функцией.** Хотя возрастные распределения двух групп CTR немного отличаются друг от друга, они распределяются приблизительно между возрастом от 4 до 7 лет. Не очень полезно для создания новой функции.
#
#     - **city**: не анализировал, потому что слишком много уникальных городов.
#
#         - **city_rank**: пользователи из города 2 уровня имеют более высокий CTR. **хорошая новая функция.**
#
#         - **residence**: провинции 11 и 22 имеют высокий CTR. **хорошая новая функция.**
#
#     - **career**: нет ни значительных высот, ни различного распределения. Не будет хорошим индикатором, если рассматривать его как отдельную функцию. Посмотрим, поможет ли это в кластеризации.
#
#     - **gender**: пол со значием 3 имеет более высокий CTR.
#
#     - **up_life_duration**: хотя от 1 до 10 имеют более высокий CTR, по сравнению с графиками распределения, эти группы не учитывают большой объем данных в общем наборе данных. Но что интересно, группа с высоким ctr имеет больше -1, а группа с низким ctr - больше 20. **хорошая новая функция.**
#
#     - **up_membership_grade**: нет ни значительных высот, ни различного распределения. Не будет хорошим индикатором, если рассматривать его как отдельную функцию. Не будет хорошим индикатором для кластеризации, поскольку распределения похожи.
#
#     - **members_life_duration**: это слишком дисбаланс. Практически все пользователи принадлежат к группе -1. Это делает анализ CTR ненадежным, потому что один щелчок в группах, отличных от -1, может оказать огромное влияние на CTR. Это не лучший показатель даже для кластеризации.
#     - **consumer_purchase**: не буду его использовать. по той же причине, что и members_life_duration
#
#     - **communication_avgonline_30d**: большинство пользователей остаются активными 10-13 часов в день. Но у незарегистрированных пользователей CTR выше. ** хороший показатель **
#
#     - **communication_onlinerate**
#         - **start_communication_onlinerate**: чем позже пользователь станет активным, тем выше будет CTR.
#
#         - **last_communication_onlinerate**: если конец в 2 часа ночи, кажется, что у него высокий CTR.
#
#         - **duration_communication_onlinerate**: чем короче время, в течение которого пользователи активны, тем выше CTR.
#
# 2. **Ads**
#     - **task_id**: при просмотре со стороны рекламы CTR всех объявлений низкий. Согласно коробчатому графику, каждая квартильная группа не слишком сильно отличается друг от друга.
#     - **adv_id**: не уверен, что это.
#
#     - **creat_type_cd**: 3 и 7 имеют более высокий CTR, чем другая группа. 4 имеет значительно более низкий CTR. приложений с высоким CTR больше 7.
#
#     - **adv_prim_id**: слишком много категорий требуют внимательного изучения.
#
#     - **dev_id**: разработчики 34 и 70 имеют значительно более высокий CTR, чем другие группы. 17, 29, 30 имеют более высокий CTR, чем остальные. У объявлений с высоким CTR больше 17, а у объявлений с низким CTR - больше 60.
#
#     - **inter_typ_cd**: Ничего слишком значительного, чтобы отличить каждую группу.
#
#     - **slot_id**: группа 12 имеет самый высокий CTR, группа с высоким CTR также имеет больше группы 12. ** хороший показатель **
#
#     - **indu_name**: 27 имеет самый высокий CTR, а 17, 36,41 и 49 - второе место. Группа с высоким CTR набирает больше в 17 и 36 годах.
#
# 3. **Apps**
#     - **spread_app_id**: распределение CTR приложений кажется немного лучше, чем ctr рекламы.
#
#     - **tags**: 13, 33, 37, 39, 40 имеют более высокий CTR. Распределение "высокий-низкий" дало до сих пор наиболее значительную разницу.
#
#     - **app_first_class**: группа с высоким ctr имеет больше 4, а группа с низким ctr - больше 2
#
#     - **app_second_class**: дистрибутивы с высоким и низким уровнем тоже имеют очень разную компоновку.
#
#     - **his_app_size**: размер приложения 16 имеет самый высокий CTR. распределение тоже существенно отличается.
#
#     - **his_on_shelf_time**: график dist показывает разницу между высокими и низкими группами
#
#     - **app_score**: хотя в нем всего две группы, распределение существенно отличается.
#
# 4. **Device**
#     - **device_name**
#
#     - **device_size**: нужно внимательнее
#
#     - **emui_dev**: 13 имеет высокий ctr, который нельзя игнорировать
#
#     - **list_time**: -1 имеет очень высокий ctr
#
#     - **device_price**: цена 6 имеет значительно высокий CTR. И у них разные раздачи.
#
# 6. **Behavior/Event**
#     - **net_type**: net_type 6 имеет лучший CTR
#
#     - **pt_d**: все записи распределяются равномерно через 7 дней. если 1 представляет понедельник, а 7 - воскресенье, то имеет смысл, чтобы люди реже нажимали на рекламу со среды по пятницу.

# %% [markdown]
# ## Дальнейшие действия

# %%
raw_df.limit(1).toPandas().columns
# Out:
# Index(['label', 'uid', 'task_id', 'adv_id', 'creat_type_cd', 'adv_prim_id',
#        'dev_id', 'inter_type_cd', 'slot_id', 'spread_app_id', 'tags',
#        'app_first_class', 'app_second_class', 'age', 'city', 'city_rank',
#        'device_name', 'device_size', 'career', 'gender', 'net_type',
#        'residence', 'his_app_size', 'his_on_shelf_time', 'app_score',
#        'emui_dev', 'list_time', 'device_price', 'up_life_duration',
#        'up_membership_grade', 'membership_life_duration', 'consume_purchase',
#        'communication_onlinerate', 'communication_avgonline_30d', 'indu_name',
#        'pt_d', 'label_int', 'start_communication_onlinerate',
#        'last_communication_onlinerate', 'duration_communication_onlinerate'],
#       dtype='object')

# %%
user_features = ["age",  
                 "city_rank",
                 "residence",
                 "career",
                 "gender",
                 "up_life_duration",
                 "up_membership_grade",
                 "membership_life_duration",
                 "consume_purchase",
                 "duration_communication_onlinerate",
                 "communication_avgonline_30d"
                ]
ads_features = ["creat_type_cd",
                "adv_prim_id",
                "dev_id",
                "inter_type_cd",
                "slot_id",
                "indu_name"]
app_features = ["tags",
                "app_first_class",
                "app_second_class",
                "his_app_size",
                "his_on_shelf_time",
                "app_score"]
device_features = ["device_size",
                   "emui_dev",
                   "list_time",
                   "device_price"]
event_features = ["net_type",
                  "pt_d"]

# %%
selected_features = user_features + ads_features + app_features \
                    + device_features + event_features

# %%
from scipy.stats import chi2_contingency
for col in selected_features:
    print(f" chi-square тест для {col} и label")
    df = raw_df.select(col, "label").groupBy("label", col).count().toPandas()
    df = pd.merge(df, df.groupby("label").sum(), on='label')
    two_way_df = pd.pivot_table(df, values='count_x', index='label', columns=col).fillna(0)
    chi2, p, dof, expect =  chi2_contingency(two_way_df)
    print(f"p-value: {p}")
    print(f"не отклоняем H0, {col} не зависит от label" if p > 0.05 else f"отклонение H0, {col} зависит от label")
    print("")
    print("="*50)
    print("")
# Out:
#  chi-square тест для age и label
# p-value: 0.0
# отклонение H0, age зависит от label
#
# ...
#
#  chi-square тест для city_rank и label
# p-value: 0.0
# отклонение H0, city_rank зависит от label
#
# ...
#
#  chi-square тест для residence и label
# p-value: 0.0
# отклонение H0, residence зависит от label
#
# ...
#
#  chi-square тест для career и label
# p-value: 0.0
# отклонение H0, career зависит от label
#
# ...
#
#  chi-square тест для gender и label
# p-value: 0.0
# отклонение H0, gender зависит от label
#
# ...
#
#  chi-square тест для up_life_duration и label
# p-value: 0.0
# отклонение H0, up_life_duration зависит от label
#
# ...
#
#  chi-square тест для up_membership_grade и label
# p-value: 0.0
# отклонение H0, up_membership_grade зависит от label
#
# ...
#
#  chi-square тест для membership_life_duration и label
# p-value: 9.185398308365572e-07
# отклонение H0, membership_life_duration зависит от label
#
# ...
#
#  chi-square тест для consume_purchase и label
# p-value: 0.0
# ...

# %% [markdown]
# p-value < 0,05 означает, что две переменные не являются независимыми.

# %%
transform_map = {}
for col in selected_features:
    df = raw_df.select(col, "label").groupBy("label", col).count().toPandas()
    df = pd.merge(df, df.groupby("label").sum(), on='label')
    df['pct'] = df['count_x'] / df['count_y']
    transform_map[col] = (df[df.label == '1'].set_index(col).pct - df[df.label == '0'].set_index(col).pct > 0).to_dict()

# %%
transform_map
# Out:
# {'age': {'-1': True,
#   '1': True,
#   '2': True,
#   '3': False,
#   '4': False,
#   '5': False,
#   '6': False,
#   '7': True},
#  'city_rank': {'2': True, '3': True, '4': False, '5': False},
#  'residence': {'11': True,
#   '12': False,
#   '13': True,
#   '14': True,
#   '15': False,
#   '16': True,
#   '17': True,
#   '18': True,
#   '19': True,
#   '20': False,
#   '21': True,
#   '22': True,
#   '23': False,
#   '24': True,
#   '25': True,
#   '26': False,
#   '27': True,
#   '28': False,
#   '29': True,
#   '30': True,
#   '31': False,
#   '32': False,
#   '33': True,
#   '34': False,
#   '35': True,
#   '36': True,
#   '37': True,
#   '38': True,
#   '39': True,
#   '40': True,
#   '41': True,
#   '42': True,
#   '43': True,
#   '44': True,
#   '45': True,
#   '46': False},
#  'career': {'10': True,
#   '2': False,
#   '3': False,
#   '4': False,
#   '5': True,
#   '6': True,
#   '7': False,
#   '8': False,
#   '9': True},
#  'gender': {'2': False, '3': True, '4': False},
# ...
